# %%
from dataclasses import dataclass

@dataclass
class Brick:
    fname: str
    lname: str
    branch: str
    conflict: str

    def __repr__(self):
        return f"Brick({self.fname!r}, {self.lname!r}, {self.branch!r}, {self.conflict!r})"

BRICKS = [Brick('NATHAN', 'SUMMERS', 'U S ARMY', 'VIETNAM WAR'), Brick('BARRY D', 'NOLL', 'U S ARMY', ''), Brick('DEAN L', 'NOLL', 'U S ARMY', 'WORLD WAR II'), Brick('ROGER A KENO', 'WERT', 'US ARMY', 'VIETNAM ERA'), Brick('CARL OWEN', 'REITZ', 'U S ARMY', 'WORLD WAR II'), Brick('MYRON W', 'REITZ', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('MICHAEL', 'CARPER', 'U S ARMY', 'VIETNAM WAR'), Brick('LAWRENCE', 'CONDO', 'U S ARMY', 'WORLD WAR II'), Brick('JOHN', 'BURGER', 'U S AIR FORCE', ''), Brick('MATTHEW', 'PARR', 'U S NAVY', 'IRAQI FREEDOM'), Brick('GEFFREY', 'MOYER', 'U S ARMY', ''), Brick('JEFF', 'STRUBLE', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('HARRY G', 'BRANDT', 'U S ARMY', 'WORLD WAR II'), Brick('RICHARD', 'WHITMAN', 'U S AIR FORCE', 'WORLD WAR II'), Brick('PETE', 'BANHOLZER', 'U S MARINE CORPS', 'KOREAN WAR'), Brick('GENE', 'McCOOL', 'U S ARMY', ''), Brick('ROBERT C', 'SMITH', 'US AIR FORCE', ''), Brick('DONALD', 'ROTE JR', 'U S MARINE CORPS', 'KOREAN WAR'), Brick('CHARLES B', 'SMITH', 'US ARMY', 'WORLD WAR I'), Brick('CARL D', 'SMITH', 'US ARMY', 'KOREAN WAR'), Brick('JOHN W', 'ZERBY', 'US ARMY', ''), Brick('DONALD E', 'SMITH', 'US ARMY AIR CORPS', 'WORLD WAR II'), Brick('GEORGE', 'MARTZ', 'U S ARMY', 'WORLD WAR II'), Brick('WILLIS H', 'YARNELL', 'U S NAVY', 'WORLD WAR II'), Brick('HARRY R', 'SPEER', 'US NAVY', 'WORLD WAR II'), Brick('DON', 'FOUST', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('FLOYD W', 'DASHEM', 'U S ARMY', 'WORLD WAR II'), Brick('KENNETH', 'FRAZIER', 'U S ARMY', 'WORLD WAR II'), Brick('A EDGAR', 'RIMMEY', 'U S AIR FORCE', ''), Brick('GERALD L', 'PIFER', 'U S NAVY', 'KOREAN WAR'), Brick('IRVIN A', 'KANE', 'AAC & USAF', 'WORLD WAR II'), Brick('DONALD', 'REFFNER', 'U S ARMY', 'WORLD WAR II'), Brick('GARY L', 'WAY', 'U S ARMY', 'VIETNAM WAR'), Brick('VERIS C', 'WAY', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('ROBERT H', 'BARNES', 'U S ARMY', 'WORLD WAR II'), Brick('RICHARD W', 'EVANS', 'US ARMY', 'WORLD WAR II'), Brick('BERNARD D', 'JOYCE', 'U S ARMY', 'WORLD WAR II'), Brick('WALTER I', 'JOYCE', 'U S NAVY', 'WORLD WAR II'), Brick('JACK', 'JOYCE', 'U S COAST GUARD', 'WORLD WAR
ARMY', 'WORLD WAR II'), Brick('HAROLD', 'STITZER', 'U S ARMY', 'WORLD WAR II'), Brick('MAX O', 'FULTZ', 'U S ARMY', 'WORLD WAR II'), Brick('RICHARD', 'DUNKLE', 'U S ARMY', 'VIETNAM WAR'), Brick('BLAINE J', 'DUNKLE', 'U S ARMY', 'WORLD WAR II'), Brick('HAROLD E', 'GRAMLEY', 'U S AIR FORCE', ''), Brick('RON', 'SUMMERS', 'USMC & US ARMY', 'VIETNAM WAR'), Brick('EDGAR A', 'TREASTER', 'U S NAVY', 'VIETNAM WAR'), Brick('CLARENCE', 'CRATER', 'U S ARMY', 'WORLD WAR II'), Brick('C S', 'HOSTERMAN JR', 'US ARMY AIR CORPS', 'WORLD WAR II'), Brick('RAYMOND', 'MUSSER', 'US ARMY', ''), Brick('RUSS', 'SCHLEIDEN', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('RONALD', 'SCHAEFFER', 'U S ARMY', 'VIETNAM WAR'), Brick('RYAN A', 'HELTMAN', 'U S ARMY', ''), Brick('BEN C', 'BAILEY', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('WAYNE K.', 'MILLER', 'U S ARMY', 'VIETNAM WAR'), Brick('CHARLES', 'HASSINGER, SR', 'U S ARMY', ''), Brick('FRANKLIN', 'CARPER', 'U S ARMY', ''), Brick('TIMOTHY', 'ARCHER', 'U S AIR FORCE', ''), Brick('JOHN W', 'PUFF', 'U S MARINE CORPS', 'WORLD WAR II'), Brick('BOWIE', 'MILLER', 'US ARMY', 'IRAQI FREEDOM'), Brick('MELVIN', 'HOLLIER', 'U S ARMY', 'WORLD WAR II'), Brick('CHARLES', 'WINGARD', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('TORRENCE', 'BARNER', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('ALLEN W', 'LEASE', 'U S NAVY', ''), Brick('GUST J', 'MADERIA', 'U S AIR FORCE', 'KOREAN WAR'), Brick('HARYY', 'HASSINGER', 'U S NAVY & AIR FORCE', 'WWII & KOREAN WAR'), Brick('JOHN R', 'MERSINGER', 'U S AIR FORCE', 'VIETNAM ERA IS'), Brick('HARRY C', 'VANADA JR', 'U S ARMY', 'KOREAN WAR'), Brick('JAMES H', 'WILSON', 'U S MARINE CORPS', ''), Brick('ROBERT D', 'SMITH', 'U S NAVY', 'KOREAN WAR'), Brick('CHARLES', 'ANDERSON JR', 'U S AIR FORCE', ''), Brick('CHARLES', 'ANDERSON', 'U S ARMY', 'WORLD WAR II'), Brick('THOMAS', 'ANDERSON', 'U S ARMY', 'VIETNAM WAR'), Brick('ROBERT', 'ANDERSON', 'U S ARMY', 'VIETNAM WAR'), Brick('STEPHEN', 'ANDERSON', 'US MARINE CORPS', ''), Brick('KIMBERLY A', 'RIMMEY', 'U S ARMY', 'IRAQI FREEDOM'), Brick('NEVIN G', 'HOMAN', 'U S MARINE CORPS', 'VIETNAM WAR'), Brick('DAVE I', 'GRAYBILL', 'U S ARMY', 'WORLD WAR II'), Brick('JIM', 'HIRONIMUS', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('CHUCK', 'NORRIS', 'U S ARMY', 'VIETNAM WAR'), Brick('KEITH', 'NORRIS SR', 'U S ARMY', 'VIETNAM WAR'), Brick('NEVIN', 'WALTERS', 'U S ARMY', 'WORLD WAR II'), Brick('ROBERT', 'WALTERS SR', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('RALPH L', 'SHOPE JR', 'U S ARMY', 'KOREAN WAR'), Brick('WILLIAM B.', 'HOMAN', 'U. S. MARINE CORPS', 'VIETNAM WAR'), Brick('RUSSELL', 'LEONARD', 'U S ARMY', 'VIETNAM WAR'), Brick('GRIER C', 'BARBOUR', 'U S AIR AIR CORPS', 'WORLD WAR II'), Brick('CAROL A.', 'CLARK-BANEY', 'US ARMY', ''), Brick('IRWIN', 'RHODE', 'US MARINE CORPS', 'VIETNAM WAR'), Brick('THOMAS', 'HEVERLY', 'US NAVY', 'VIETNAM WAR'), Brick('LLOYD L', 'WENRICK', 'U S ARMY', 'VIETNAM WAR'), Brick('THOMAS S.', 'STONER', 'U S ARMY', ''), Brick('HAROLD', 'SAMPSELL', 'U S ARMY', 'VIETNAM WAR'), Brick('PHILIP', 'BRADFORD', 'U S ARMY', 'KOREAN WAR'), Brick('HAROLD', 'BRADFORD', 'U S NAVY', 'WORLD WAR II'), Brick('JAMES D', 'YOUNG', 'U S NAVY', 'W W II & KOREA'), Brick('C L "FAT"', 'PRICE', 'U S NAVY', 'WORLD WAR II'), Brick('DENNIS', 'PRICE', 'U S NAVY', 'VIETNAM WAR'), Brick('MARVIN', 'PRICE', 'U S NAVY', 'WORLD WAR II'), Brick('EUGENE I', 'PRICE', 'U S MARINE CORPS', 'WORLD WAR II'), Brick('WILLIAM W.', 'STUTER', 'U S MARINE CORPS', ''), Brick('R DALE', 'SHIELDS', 'ARMY AIR CORPS', 'WORLD WAR II'), Brick('WILLIAM C', 'SCHULTZ', 'US ARMY', 'KOREAN WAR'), Brick('JAMES M', 'COLE', 'U S ARMY', ''), Brick('VINTON H', 'LINGLE', 'U S NAVY', 'WORLD WAR II'), Brick('MAHLON', 'McMURTRIE', 'US MARINE CORPS', 'VIETNAM WAR'), Brick('KENNETH E', 'HAUPT SR', 'U S ARMY', 'KOREAN WAR'), Brick('LARRY H', 'YOUNG', 'U S ARMY', 'VIETNAM WAR'), Brick('KEN', 'SPANGLER', 'U S ARMY', 'VIETNAM WAR'), Brick('BUDD L', 'HOY', 'U S ARMY', 'WW II & KOREAN WAR'), Brick('WALTER', 'MAYES', 'US MARINE CORPS', 'KOREAN WAR'), Brick('MICHAEL', 'MAYES', 'U S ARMY', 'IRAQI FREEDOM'), Brick('RONALD', 'MAYES SR', 'U.S.M.C', 'VIETNAM ERA'), Brick('DONALD R', 'MAYES', 'U S ARMY', 'KOREAN WAR'), Brick('KENNETH', 'BOWER', 'U S AIR FORCE', 'KOREAN WAR'), Brick('RALPH E', 'LONG', 'U S ARMY', 'WORLD WAR II'), Brick('DONALD', 'FETTEROLF', 'U S AIR FORCE', 'KOREAN WAR'), Brick('DENNIS W', 'ROYER', 'U S ARMY', 'VIETNAM WAR'), Brick('GLENN C', 'DERSHEM', 'U S NAVY', 'WORLD WAR II'), Brick('WILLARD T', 'ROYER', 'U S ARMY', 'WORLD WAR II'), Brick('GEARHARD', 'ROYER', 'U S ARMY', ''), Brick('JUSTIN', 'WITHERITE', 'U S ARMY', ''), Brick('HARRY M', 'BROWN', 'U S ARMY', 'WORLD WAR II'), Brick('ROY C', 'HOMAN', 'U S ARMY', ''), Brick('LEWIS', 'GARBRICK', 'U S NAVY', 'WORLD WAR II'), Brick('FRED', 'BURLINGAME', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('CHARLES H', 'ORT', 'U S NAVY', 'WORLD WAR II'), Brick('C EUGENE', 'DUTROW', 'US ARMY', 'KOREAN WAR'), Brick('WILLIAM', 'ALLISON', 'U S NAVY', 'VIETNAM WAR'), Brick('LEE S', 'HALL', 'U S ARMY', 'WORLD WAR II'), Brick('A R', 'McNITT', 'U S ARMY', 'KOREAN WAR'), Brick('JOHN D', 'KNARR', 'U S ARMY', 'WORLD WAR II'), Brick('PHILLIP', 'CRAUL', 'U S ARMY', ''), Brick('LARRY R', 'MOYER', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('CLARENCE', 'OAKES', 'U S MARINE CORPS', 'VIETNAM WAR'), Brick('JOHN', 'NWRANSKI', 'U S ARMY', 'WORLD WAR II'), Brick('MICHAEL', 'MUSSER', 'U S AIR FORCE', 'PERSIAN GULF'), Brick('RICHARD', 'RUNKLE', 'US AIR FORCE', 'KOREAN WAR'), Brick('RICHARD E', 'SMALLEY', 'U S ARMY', 'KOREAN WAR'), Brick('J. E.', 'CHIOVAROU', 'U S NAVY', ''), Brick('MICHAEL', 'WENRICK', 'U S ARMY', 'IRAQI FREEDOM'), Brick('W "BUCK"', 'WENRICK', 'U S ARMY', ''), Brick('MAURICE', 'NEWMAN', 'U S MARINE CORPS', 'VIETNAM WAR'), Brick('CLYDE', 'BOYER', 'U S ARMY', 'WORLD WAR II'), Brick('NICK', 'LESNIAK', 'U S ARMY', ''), Brick('STAN', 'LESNIAK', 'U S ARMY & NAVY', ''), Brick('MICHAEL P', 'McDERMOTT', 'U S NAVY', ''), Brick('MIKE', 'McCLENAHAN', 'US ARMY', 'KOREAN WAR'), Brick('ROBIN', 'McCLENAHAN', 'US ARMY', ''), Brick('PAT', 'McCLENAHAN', 'U S ARMY', ''), Brick('MILES W', 'WOLFE', 'U S ARMY', 'WORLD WAR II'), Brick('TERRY L', 'ALEXANDER', 'U S ARMY', 'VIETNAM WAR'), Brick('TIM TR', 'ROSS', 'U S ARMY', 'VIETNAM ERA'), Brick('ROBERT S.', 'ROSS', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('ARDELL', 'GROSS SR', 'U S NAVY', 'WORLD WAR II'), Brick('JOHN I', 'STONER', 'U S ARMY', 'VIETNAM WAR'), Brick('LEWIS A', 'CRADER', 'U S ARMY', 'WORLD WAR 1'), Brick('HAROLD', 'WINGARD', 'US AIR FORCE', 'VIETNAM WAR'), Brick('DOYLE', 'WINGARD', 'U S NAVY', 'WORLD WAR II'), Brick('HENRY', 'WINGARD', 'U S ARMY', 'WORLD WAR II'), Brick('JAY', 'WINGARD', 'ARMY AIR CORPS', 'WORLD WAR II'), Brick('STUART', 'WINGARD', 'U S ARMY', 'WORLD WAR II'), Brick('ALLEN R', 'WINGARD', 'U S ARMY', 'WORLD WAR 1'), Brick('TIMOTH R', 'LAKE', 'U S NAVY', 'PERSIAN GULF'), Brick('MIKE', 'LAKE', 'U S ARMY', 'VIETNAM WAR'), Brick('ROY K', 'DUNKLEBARGER', 'U S ARMY', 'WORLD WAR II'), Brick('GEO RUSS', 'SMITH', 'U S AIR FORCE', 'KOREAN WAR'), Brick('LEE C', 'DORMAN', 'U S NAVY', ''), Brick('NEVIN E', 'LONG', 'U S ARMY', ''), Brick('RAYMOND', 'MUSSER', 'U S ARMY', 'WORLD WAR II'), Brick('STEPHEN L', 'FOUST', 'U S ARMY', 'VIETNAM ERA'), Brick('GLENN', 'BRESSLER', 'U S ARMY', 'WORLD WAR II'), Brick('DENNIS', 'BRESSLER', 'U S ARMY', 'VIETNAM WAR'), Brick('JAMES V', 'SWALES', 'U S ARMY', 'WORLD WAR II'), Brick('RONALD J', 'HORNER', 'U S ARMY', 'VIETNAM WAR'), Brick('DENNIS', 'ROYER', 'U S AIR FORCE', ''), Brick('DEAN B', 'RIPKA', 'U S ARMY', 'WORLD WAR II'), Brick('KENNETH D', 'ROYER', 'U S AIR FORCE', 'VIETNAM WAR'), Brick('PAUL A', 'GROVE', 'U S ARMY', 'WORLD WAR II'), Brick('CARL W', 'ROYER', 'U S AIR FORCE', 'KOREAN WAR'), Brick('SHANE', 'ROYER', 'U S ARMY', 'PERSIAN GULF'), Brick('SHANE', 'ROYER', 'U S ARMY', 'IRAQI FREEDOM'), Brick('ARTHUR', 'RIDENOUR SR', 'US MARINE CORPS', 'VIETNAM WAR'), Brick('TERRY', 'CHAMBERLIN', 'U S ARMY', 'VIETNAM ERA'), Brick('MAHLON D', 'NEVEL', 'U S ARMY', 'WORLD WAR II'), Brick('WILLIAM E', 'MILLS', 'U S ARMY', 'VIETNAM WAR'), Brick('ARDEL H', 'VONADA KIA', 'U S ARMY AIR CORPS', 'WORLD WAR II'), Brick('HOBIE', 'KISTLER', 'U S NAVY', 'NAVAL REACTORS'), Brick('STEPHEN', 'KUCAS', 'U S ARMY, KIA', 'KOREAN & V-NAM WAR'), Brick('MICHAEL', 'KRONER', 'U S ARMY', 'IRAQI FREEDOM, KIA'), Brick('CHESTER', 'PLETCHER', 'U S ARMY', 'WORLD WAR II, KIA'), Brick('HAROLD W', 'SMITH', 'U S ARMY AIR CORPS', 'WORLD WAR II, KIA')]

# %%
import pandas as pd

d = {'fname': [], 'lname': [], 'branch': [], 'conflict': []}
for brick in BRICKS:
    d['fname'].append(brick.fname)
    d['lname'].append(brick.lname)
    d['branch'].append(brick.branch)
    d['conflict'].append(brick.conflict)

df = pd.DataFrame(d)

# %%
branch_counts = df.branch.value_counts()

# %%
branch_counts.plot.bar(color=['#D4BF91', '#003087', '#000048', '#A6192E', '#F2531B'], title='Branch')
# Out:
# <Axes: title={'center': 'Branch'}>

# %%
conflict_counts = df.conflict.value_counts()

# %%
conflict_counts.plot.pie(autopct='%1.1f%%', title='Conflict')
# Out:
# <Axes: title={'center': 'Conflict'}>

# %%
casualty_counts = df.casualty.value_counts()

# %%
casualty_counts.plot.pie(title='Casualty')
# Out:
# <Axes: title={'center': 'Casualty'}>
